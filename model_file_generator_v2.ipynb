# %% [markdown]
# # 0. Set-up

# %%
## Import packages
import gc
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
user = os.getenv('USERNAME')
shared_workspace = '/home/mdawkins/modelling_club'
user_dir = os.path.join(shared_workspace, user)

raw_data_dir = os.path.join(shared_workspace, 'raw_data')
engineered_data_dir = os.path.join(shared_workspace, 'raw_data_lfs')

model_file_output_dir = '/home/mdawkins/modelling_club/raw_data_lfs'

# %% [markdown]
# # 1. Initialise model file

# %%
model_file = pd.read_csv(engineered_data_dir + '/ids2split.csv',index_col='SK_ID_CURR')

# %% [markdown]
# # 2. Application data

# %%
application = pd.read_csv(engineered_data_dir + '/engineered/application/application.csv',index_col='SK_ID_CURR')

# %%
model_file = model_file.merge(application, on='SK_ID_CURR', how='left')

# %% [markdown]
# # 3. Previous

# %%
previous = pd.read_pickle(engineered_data_dir + '/engineered/previous/previous_payments.pkl')
previous = previous.set_index("SK_ID_CURR")

# %%
model_file = model_file.merge(previous, on='SK_ID_CURR', how='left')

# %% [markdown]
# # 4. POS CASH balance data

# %%
pos_cash_balance = pd.read_pickle(engineered_data_dir + '/engineered/POS_CASH_balance/pos_features.pkl')
# pos_cash_balance has SK_ID_CURR as the index already

# %%
model_file = model_file.merge(pos_cash_balance, on='SK_ID_CURR', how='left')

# %% [markdown]
# # 5. Bureau balance data

# %%
bureau_balance = pd.read_pickle(engineered_data_dir + '/engineered/bureau_balance/bureau_balance_features.pkl')
# bureau_balance has SK_ID_CURR as the index already

# %%
model_file = model_file.merge(bureau_balance, on='SK_ID_CURR', how='left')

# %% [markdown]
# # 6. Credit card data

# %% [markdown]
# None currently available

# %% [markdown]
# # 7. Bureau data

# %% [markdown]
# ## Mortgage data

# %% [markdown]
# - Active

# %%
Active_Mortgage_Clean = pd.read_pickle(engineered_data_dir + '/engineered/bureau/Active_Mortgage_Clean.pkl')
Active_Mortgage_Clean = Active_Mortgage_Clean.add_prefix('ACT_MORTG_')

# %%
model_file = model_file.merge(Active_Mortgage_Clean, on='SK_ID_CURR', how='left')

# %% [markdown]
# - Closed

# %%
Closed_Mortgage_Clean = pd.read_csv(engineered_data_dir + '/engineered/bureau/Closed_Mortgage_Clean.csv',index_col='SK_ID_CURR')
Closed_Mortgage_Clean = Closed_Mortgage_Clean.add_prefix('CLD_MORTG_')

# %%
model_file = model_file.merge(Closed_Mortgage_Clean, on='SK_ID_CURR', how='left')

# %% [markdown]
# ## Consumer Credit data

# %% [markdown]
# - Active

# %%
Active_ConsumerCredit_Agg = pd.read_csv(engineered_data_dir + '/engineered/bureau/Active_ConsumerCredit_Agg.csv',index_col=['SK_ID_CURR'])
Active_ConsumerCredit_Agg = Active_ConsumerCredit_Agg.add_prefix('ACT_CONCRED_')

# %%
model_file = model_file.merge(Active_ConsumerCredit_Agg, on='SK_ID_CURR', how='left')

# %%
Active_ConsumerCredit_Agg_Date = pd.read_csv(engineered_data_dir + '/engineered/bureau/Active_ConsumerCredit_Agg_Date.csv',index_col=['DATE_RANGE','SK_ID_CURR'])
Active_ConsumerCredit_Agg_Date = Active_ConsumerCredit_Agg_Date.add_prefix('ACT_CONCRED_')
Active_ConsumerCredit_Dates = Active_ConsumerCredit_Agg_Date.index.get_level_values("DATE_RANGE").unique()

# %%
for d in Active_ConsumerCredit_Dates:
    model_file = model_file.merge(Active_ConsumerCredit_Agg_Date.loc[d].add_prefix('D'+str(d)+'_'), on='SK_ID_CURR', how='left')

# %% [markdown]
# - Closed

# %%
Closed_ConsumerCredit_Agg = pd.read_csv(engineered_data_dir + '/engineered/bureau/Closed_ConsumerCredit_Agg.csv',index_col=['SK_ID_CURR'])
Closed_ConsumerCredit_Agg = Closed_ConsumerCredit_Agg.add_prefix('CLD_CONCRED_')

# %%
model_file = model_file.merge(Closed_ConsumerCredit_Agg, on='SK_ID_CURR', how='left')

# %%
Closed_ConsumerCredit_Agg_Date = pd.read_csv(engineered_data_dir + '/engineered/bureau/Closed_ConsumerCredit_Agg_Date.csv',index_col=['DATE_RANGE','SK_ID_CURR'])
Closed_ConsumerCredit_Agg_Date = Closed_ConsumerCredit_Agg_Date.add_prefix('CLD_CONCRED_')
Closed_ConsumerCredit_Dates = Closed_ConsumerCredit_Agg_Date.index.get_level_values("DATE_RANGE").unique()

# %%
for d in Closed_ConsumerCredit_Dates:
    model_file = model_file.merge(Closed_ConsumerCredit_Agg_Date.loc[d].add_prefix('D'+str(d)+'_'), on='SK_ID_CURR', how='left')

# %% [markdown]
# ## Credit Card data

# %% [markdown]
# - Active

# %%
Active_CreditCard_Agg = pd.read_csv(engineered_data_dir + '/engineered/bureau/Active_CreditCard_Agg.csv',index_col=['SK_ID_CURR'])
Active_CreditCard_Agg = Active_CreditCard_Agg.add_prefix('ACT_CREDCARD_')

# %%
model_file = model_file.merge(Active_CreditCard_Agg, on='SK_ID_CURR', how='left')

# %%
Active_CreditCard_Agg_Date = pd.read_csv(engineered_data_dir + '/engineered/bureau/Active_CreditCard_Agg_Date.csv',index_col=['DATE_RANGE','SK_ID_CURR'])
Active_CreditCard_Agg_Date = Active_CreditCard_Agg_Date.add_prefix('ACT_CREDCARD_')
Active_CreditCard_Dates = Active_CreditCard_Agg_Date.index.get_level_values("DATE_RANGE").unique()

# %%
for d in Active_CreditCard_Dates:
    model_file = model_file.merge(Active_CreditCard_Agg_Date.loc[d].add_prefix('D'+str(d)+'_'), on='SK_ID_CURR', how='left')

# %% [markdown]
# - Closed

# %%
Closed_CreditCard_Agg = pd.read_csv(engineered_data_dir + '/engineered/bureau/Closed_CreditCard_Agg.csv',index_col=['SK_ID_CURR'])
Closed_CreditCard_Agg = Closed_CreditCard_Agg.add_prefix('CLD_CREDCARD_')

# %%
model_file = model_file.merge(Closed_CreditCard_Agg, on='SK_ID_CURR', how='left')

# %%
Closed_CreditCard_Agg_Date = pd.read_csv(engineered_data_dir + '/engineered/bureau/Closed_CreditCard_Agg_Date.csv',index_col=['DATE_RANGE','SK_ID_CURR'])
Closed_CreditCard_Agg_Date = Closed_CreditCard_Agg_Date.add_prefix('CLD_CREDCARD_')
Closed_CreditCard_Dates = Closed_CreditCard_Agg_Date.index.get_level_values("DATE_RANGE").unique()

# %%
for d in Closed_CreditCard_Dates:
    model_file = model_file.merge(Closed_CreditCard_Agg_Date.loc[d].add_prefix('D'+str(d)+'_'), on='SK_ID_CURR', how='left')

# %% [markdown]
# # Other

# %% [markdown]
# - Active

# %%
Active_Other_Agg = pd.read_csv(engineered_data_dir + '/engineered/bureau/Active_Other_Agg.csv',index_col=['SK_ID_CURR'])
Active_Other_Agg = Active_Other_Agg.add_prefix('ACT_OTHER_')

# %%
model_file = model_file.merge(Active_Other_Agg, on='SK_ID_CURR', how='left')

# %%
# Active_Other_Agg_Date = pd.read_csv(engineered_data_dir + '/engineered/bureau/Active_Other_Agg_Date.csv',index_col=['DATE_RANGE','SK_ID_CURR'])
# Active_Other_Agg_Date = Active_Other_Agg_Date.add_prefix('ACT_OTHER_')
# Active_Other_Dates = Active_Other_Agg_Date.index.get_level_values("DATE_RANGE").unique()

# %%
# for d in Active_Other_Dates:
#     model_file = model_file.merge(Active_Other_Agg_Date.loc[d].add_prefix('D'+str(d)+'_'), on='SK_ID_CURR', how='left')

# %% [markdown]
# - Closed

# %%
Closed_Other_Agg = pd.read_csv(engineered_data_dir + '/engineered/bureau/Closed_Other_Agg.csv',index_col=['SK_ID_CURR'])
Closed_Other_Agg = Closed_Other_Agg.add_prefix('CLD_OTHER_')

# %%
model_file = model_file.merge(Closed_Other_Agg, on='SK_ID_CURR', how='left')

# %%
# Closed_Other_Agg_Date = pd.read_csv(engineered_data_dir + '/engineered/bureau/Closed_Other_Agg_Date.csv',index_col=['DATE_RANGE','SK_ID_CURR'])
# Closed_Other_Agg_Date = Closed_Other_Agg_Date.add_prefix('CLD_OTHER_')
# Closed_Other_Dates = Closed_Other_Agg_Date.index.get_level_values("DATE_RANGE").unique()

# %%
# for d in Closed_Other_Dates:
#     model_file = model_file.merge(Closed_Other_Agg_Date.loc[d].add_prefix('D'+str(d)+'_'), on='SK_ID_CURR', how='left')

# %% [markdown]
# ## Sold Debt data

# %%
Sold_Agg = pd.read_csv(engineered_data_dir + '/engineered/bureau/Sold_Agg.csv',index_col=['SK_ID_CURR'])
Sold_Agg = Sold_Agg.add_prefix('SOLD_')

# %%
# model_file = model_file.merge(Sold_Agg, on='SK_ID_CURR', how='left')

# %% [markdown]
# ### Final model file

# %%
# model_file = model_file.drop(["DAYS_EMPLOYED","DAYS_BIRTH","NAME_INCOME_TYPE"],axis=1)

# %%
model_file
# Out:
#                  SPLIT  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 113072      validation     0.0    Revolving loans           M            Y
# 225465           train     0.0         Cash loans           F            N
# 260656           train     0.0         Cash loans           F            N
# 445761      validation     0.0         Cash loans           F            N
# 421144           train     0.0         Cash loans           F            N
# ...                ...     ...                ...         ...          ...
# 256859           train     0.0         Cash loans           M            Y
# 246902           train     0.0         Cash loans           F            N
# 287398      validation     0.0         Cash loans           F            N
# 282658           train     0.0    Revolving loans           M            Y
# 370166      validation     0.0         Cash loans           F            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 113072                   Y             0          283500.0    180000.0
# 225465                   Y             0           67500.0    182016.0
# 260656                   Y             0          112500.0    315000.0
# 445761                   Y             0          675000.0   2000000.0
# 421144                   Y             0          180000.0    679500.0
# ...                    ...           ...               ...         ...
# 256859                   Y             1          180000.0    313438.5
# 246902                   Y             0           90000.0    528633.0
# 287398                   N             0           67500.0    315000.0
# 282658                   N             0          247500.0    675000.0
# 370166                   N             1          157500.0    990432.0
#
#             AMT_ANNUITY  ...  ACT_OTHER_AMT_ANNUITY_MAX ACT_OTHER_COUNT  \
# SK_ID_CURR               ...
# 113072           9000.0  ...                        NaN             NaN
# 225465          10291.5  ...                        NaN             NaN
# 260656          17716.5  ...                        NaN             NaN
# 445761          59301.0  ...                        NaN             NaN
# 421144          19867.5  ...                        NaN             NaN
# ...                 ...  ...                        ...             ...
# 256859          22842.0  ...                        NaN             NaN
# 246902          25560.0  ...                        NaN             NaN
# 287398          13342.5  ...                        NaN             NaN
# 282658          33750.0  ...                        NaN             NaN
# 370166          32863.5  ...                        NaN             NaN
#
#            CLD_OTHER_AMT_CREDIT_MAX_OVERDUE CLD_OTHER_AMT_CREDIT_SUM  \
# SK_ID_CURR
# 113072                                  NaN                      NaN
# 225465                                  NaN                      NaN
# 260656                                  NaN                      NaN
# 445761                                  NaN                      NaN
# 421144                                  NaN                      NaN
# ...                                     ...                      ...
# 256859                                  NaN                      NaN
# 246902                                  NaN                      NaN
# 287398                                  NaN                      NaN
# 282658                                  NaN                      NaN
# 370166                                  NaN                      NaN
#
#            CLD_OTHER_AMT_CREDIT_SUM_MAX CLD_OTHER_AMT_CREDIT_SUM_DEBT  \
# SK_ID_CURR
# 113072                              NaN                           NaN
# 225465                              NaN                           NaN
# 260656                              NaN                           NaN
# 445761                              NaN                           NaN
# 421144                              NaN                           NaN
# ...                                 ...                           ...
# 256859                              NaN                           NaN
# 246902                              NaN                           NaN
# 287398                              NaN                           NaN
# 282658                              NaN                           NaN
# 370166                              NaN                           NaN
#
#             CLD_OTHER_AMT_CREDIT_SUM_DEBT_MAX  CLD_OTHER_AMT_ANNUITY_DEBT  \
# SK_ID_CURR
# 113072                                    NaN                         NaN
# 225465                                    NaN                         NaN
# 260656                                    NaN                         NaN
# 445761                                    NaN                         NaN
# 421144                                    NaN                         NaN
# ...                                       ...                         ...
# 256859                                    NaN                         NaN
# 246902                                    NaN                         NaN
# 287398                                    NaN                         NaN
# 282658                                    NaN                         NaN
# 370166                                    NaN                         NaN
#
#             CLD_OTHER_AMT_ANNUITY_DEBT_MAX  CLD_OTHER_COUNT
# SK_ID_CURR
# 113072                                 NaN              NaN
# 225465                                 NaN              NaN
# 260656                                 NaN              NaN
# 445761                                 NaN              NaN
# 421144                                 NaN              NaN
# ...                                    ...              ...
# 256859                                 NaN              NaN
# 246902                                 NaN              NaN
# 287398                                 NaN              NaN
# 282658                                 NaN              NaN
# 370166                                 NaN              NaN
#
# [215257 rows x 508 columns]

# %%
model_file.isna().sum().sort_values().to_dict()
# Out:
# {'SPLIT': 0,
#  'REG_REGION_NOT_WORK_REGION': 0,
#  'LIVE_REGION_NOT_WORK_REGION': 0,
#  'REG_CITY_NOT_LIVE_CITY': 0,
#  'REG_CITY_NOT_WORK_CITY': 0,
#  'LIVE_CITY_NOT_WORK_CITY': 0,
#  'REGION_ID': 0,
#  'HIGHER_ED': 0,
#  'YEARS_BIRTH': 0,
#  'CREDIT_IN_YEARS_INCOME': 0,
#  'FLAG_DOCUMENT_21': 0,
#  'FLAG_DOCUMENT_20': 0,
#  'FLAG_DOCUMENT_19': 0,
#  'FLAG_DOCUMENT_18': 0,
#  'FLAG_DOCUMENT_17': 0,
#  'FLAG_DOCUMENT_16': 0,
#  'FLAG_DOCUMENT_15': 0,
#  'FLAG_DOCUMENT_14': 0,
#  'FLAG_DOCUMENT_13': 0,
#  'FLAG_DOCUMENT_12': 0,
#  'FLAG_DOCUMENT_11': 0,
#  'FLAG_DOCUMENT_10': 0,
#  'FLAG_DOCUMENT_9': 0,
#  'FLAG_DOCUMENT_8': 0,
#  'FLAG_DOCUMENT_7': 0,
#  'FLAG_DOCUMENT_6': 0,
#  'FLAG_DOCUMENT_5': 0,
#  'FLAG_DOCUMENT_4': 0,
#  'FLAG_DOCUMENT_3': 0,
#  'FLAG_DOCUMENT_2': 0,
#  'REG_REGION_NOT_LIVE_REGION': 0,
#  'HOUR_APPR_PROCESS_START': 0,
#  'ORGANIZATION_TYPE': 0,
#  'REGION_RATING_CLIENT_W_CITY': 0,
#  'DAYS_BIRTH': 0,
#  'REGION_POPULATION_RELATIVE': 0,
#  'NAME_HOUSING_TYPE': 0,
#  'NAME_FAMILY_STATUS': 0,
#  'NAME_EDUCATION_TYPE': 0,
#  'NAME_INCOME_TYPE': 0,
#  'DAYS_REGISTRATION': 0,
#  'AMT_CREDIT': 0,
#  'CNT_CHILDREN': 0,
#  'FLAG_OWN_REALTY': 0,
#  'FLAG_OWN_CAR': 0,
#  'CODE_GENDER': 0,
#  'NAME_CONTRACT_TYPE': 0,
#  'TARGET': 0,
#  'AMT_INCOME_TOTAL': 0,
#  'WEEKDAY_APPR_PROCESS_START': 0,
#  'DAYS_ID_PUBLISH': 0,
#  'FLAG_EMP_PHONE': 0,
#  'FLAG_PHONE': 0,
#  'FLAG_EMAIL': 0,
#  'REGION_RATING_CLIENT': 0,
#  'FLAG_WORK_PHONE': 0,
#  'FLAG_MOBIL': 0,
#  'FLAG_CONT_MOBILE': 0,
#  'DAYS_LAST_PHONE_CHANGE': 1,
#  'CNT_FAM_MEMBERS': 2,
#  'INCOME_PER_FAMILY_MEMBER': 2,
#  'LOAN_LENGTH': 9,
#  'AMT_ANNUITY': 9,
#  'LOAN_STRESS': 9,
#  'PRICE_CREDIT_RATIO': 199,
#  'DOWN_PAYMENT': 199,
#  'AMT_GOODS_PRICE': 199,
#  'EXT_SOURCE_2': 482,
#  'OBS_60_CNT_SOCIAL_CIRCLE': 731,
#  'DEF_60_CNT_SOCIAL_CIRCLE': 731,
#  'OBS_30_CNT_SOCIAL_CIRCLE': 731,
#  'DEF_30_CNT_SOCIAL_CIRCLE': 731,
#  'NAME_TYPE_SUITE': 908,
#  'PREV_HOUR_APPR_PROCESS_START_MEAN': 11473,
#  'PREV_APPLICATION_CREDIT_DIFF_MEAN': 11473,
#  'PREV_HOUR_APPR_PROCESS_START_MAX': 11473,
#  'PREV_DAYS_DECISION_MIN': 11473,
#  'PREV_HOUR_APPR_PROCESS_START_MIN': 11473,
#  'PREV_SK_ID_PREV_NUNIQUE': 11473,
#  'PREV_DAYS_DECISION_MEAN': 11473,
#  'PREV_APPLICATION_CREDIT_DIFF_MAX': 11473,
#  'PREV_DAYS_DECISION_MAX': 11473,
#  'PREV_APPLICATION_CREDIT_DIFF_MIN': 11473,
#  'PREV_APPLICATION_CREDIT_RATIO_MIN': 11638,
#  'PREV_APPLICATION_CREDIT_RATIO_MAX': 11638,
#  'PREV_APPLICATION_CREDIT_RATIO_MEAN': 11638,
#  'PREV_CNT_PAYMENT_MEAN': 11773,
#  'PREV_CNT_PAYMENT_MAX': 11773,
#  'PREV_CREDIT_TO_ANNUITY_RATIO_MEAN': 11774,
#  'PREV_AMT_ANNUITY_MEAN': 11774,
#  'PREV_AMT_ANNUITY_MAX': 11774,
#  'PREV_AMT_ANNUITY_MIN': 11774,
#  'PREV_CREDIT_TO_ANNUITY_RATIO_MAX': 11774,
#  'PREV_APPROVED_HOUR_APPR_PROCESS_START_MIN': 12175,
#  'PREV_APPROVED_HOUR_APPR_PROCESS_START_MAX': 12175,
#  'PREV_APPROVED_APPLICATION_CREDIT_DIFF_MAX': 12175,
#  'PREV_APPROVED_SK_ID_PREV_NUNIQUE': 12175,
#  'PREV_APPROVED_CNT_PAYMENT_MEAN': 12175,
#  'PREV_APPROVED_AMT_CREDIT_MEAN': 12175,
#  'PREV_APPROVED_AMT_CREDIT_MAX': 12175,
#  'PREV_APPROVED_AMT_CREDIT_MIN': 12175,
#  'PREV_APPROVED_CNT_PAYMENT_MAX': 12175,
#  'PREV_APPROVED_DAYS_DECISION_MIN': 12175,
#  'PREV_APPROVED_DAYS_DECISION_MEAN': 12175,
#  'PREV_APPROVED_AMT_ANNUITY_MEAN': 12176,
#  'PREV_APPROVED_AMT_ANNUITY_MIN': 12176,
#  'PREV_APPROVED_AMT_ANNUITY_MAX': 12176,
#  'PREV_APPROVED_APPLICATION_CREDIT_RATIO_MIN': 12181,
#  'PREV_APPROVED_APPLICATION_CREDIT_RATIO_MAX': 12181,
#  'PREV_APPROVED_APPLICATION_CREDIT_RATIO_MEAN': 12181,
#  'PREV_APPROVED_CREDIT_TO_ANNUITY_RATIO_MAX': 12182,
#  'PREV_APPROVED_SIMPLE_INTERESTS_MAX': 12182,
#  'PREV_APPROVED_SIMPLE_INTERESTS_MEAN': 12182,
#  'PREV_APPROVED_SIMPLE_INTERESTS_MIN': 12182,
#  'PREV_APPROVED_CREDIT_TO_ANNUITY_RATIO_MEAN': 12182,
#  'PREV_APPROVED_DAYS_LAST_DUE_DIFF_MAX': 12392,
#  'PREV_APPROVED_DAYS_FIRST_DRAWING_MEAN': 12392,
#  'PREV_APPROVED_DAYS_FIRST_DUE_MIN': 12392,
#  'PREV_APPROVED_DAYS_FIRST_DUE_MEAN': 12392,
#  'PREV_APPROVED_DAYS_LAST_DUE_DIFF_MEAN': 12392,
#  'PREV_APPROVED_DAYS_TERMINATION_MEAN': 12392,
#  'PREV_APPROVED_DAYS_LAST_DUE_1ST_VERSION_MIN': 12392,
#  'PREV_APPROVED_DAYS_FIRST_DRAWING_MAX': 12392,
#  'PREV_APPROVED_DAYS_LAST_DUE_1ST_VERSION_MEAN': 12392,
#  'PREV_APPROVED_DAYS_LAST_DUE_MAX': 12392,
#  'PREV_APPROVED_DAYS_LAST_DUE_MEAN': 12392,
#  'PREV_APPROVED_DAYS_LAST_DUE_DIFF_MIN': 12392,
#  'PREV_APPROVED_DAYS_LAST_DUE_1ST_VERSION_MAX': 12392,
#  'POS_ACTIVE_SUM': 12642,
#  'POS_IS_ACTIVE_FLAG': 12642,
#  'POS_DPD_AVG': 12642,
#  'POS_DPD_MAX': 12642,
#  'PREV_APPROVED_AMT_GOODS_PRICE_MAX': 12825,
#  'PREV_AMT_DOWN_PAYMENT_MAX': 23644,
#  'PREV_RATE_DOWN_PAYMENT_MEAN': 23644,
#  'PREV_RATE_DOWN_PAYMENT_MAX': 23644,
#  'PREV_DOWN_PAYMENT_TO_CREDIT_MEAN': 23644,
#  'PREV_AMT_DOWN_PAYMENT_MEAN': 23644,
#  'PREV_APPROVED_AMT_DOWN_PAYMENT_MAX': 25261,
#  'PREV_Consumer_DAYS_DECISION_MAX': 26761,
#  'PREV_Consumer_APPLICATION_CREDIT_DIFF_MIN': 26761,
#  'PREV_Consumer_AMT_CREDIT_SUM': 26761,
#  'PREV_Consumer_APPLICATION_CREDIT_RATIO_MEAN': 26838,
#  'PREV_Consumer_APPLICATION_CREDIT_RATIO_MAX': 26838,
#  'PREV_Consumer_APPLICATION_CREDIT_RATIO_MIN': 26838,
#  'PREV_Consumer_CNT_PAYMENT_MEAN': 27456,
#  'PREV_Consumer_SIMPLE_INTERESTS_MAX': 27457,
#  'PREV_Consumer_SIMPLE_INTERESTS_MEAN': 27457,
#  'PREV_Consumer_SIMPLE_INTERESTS_MIN': 27457,
#  'PREV_Consumer_AMT_ANNUITY_MAX': 27457,
#  'PREV_Consumer_AMT_ANNUITY_MEAN': 27457,
#  'PREV_DAYS_TERMINATION_MAX': 28215,
#  'PREV_Consumer_DAYS_LAST_DUE_1ST_VERSION_MAX': 28922,
#  'PREV_Consumer_DAYS_LAST_DUE_1ST_VERSION_MEAN': 28922,
#  'AMT_REQ_CREDIT_BUREAU_DAY': 29028,
#  'AMT_REQ_CREDIT_BUREAU_YEAR': 29028,
#  'AMT_REQ_CREDIT_BUREAU_QRT': 29028,
#  'AMT_REQ_CREDIT_BUREAU_MON': 29028,
#  'AMT_REQ_CREDIT_BUREAU_HOUR': 29028,
#  'AMT_REQ_CREDIT_BUREAU_WEEK': 29028,
#  'DAYS_EMPLOYED': 38695,
#  'DAYS_EMPLOYED_PERCENT': 38695,
#  'YEARS_EMPLOYED': 38695,
#  'EXT_SOURCE_3': 42691,
#  'POS_DPD_LAST_24_MONTHS': 43313,
#  'PREV_LAST24M_NAME_CONTRACT_TYPE_Consumer loans_MEAN': 50304,
#  'PREV_LAST24M_APPLICATION_CREDIT_DIFF_MIN': 50304,
#  'PREV_LAST24M_DAYS_DECISION_MEAN': 50304,
#  'PREV_LAST24M_DAYS_DECISION_MIN': 50304,
#  'PREV_LAST24M_AMT_CREDIT_SUM': 50304,
#  'PREV_LAST24M_NAME_CONTRACT_TYPE_Revolving loans_MEAN': 50304,
#  'PREV_LAST24M_NAME_CONTRACT_TYPE_Cash loans_MEAN': 50304,
#  'PREV_APPLICATION_CREDIT_RATIO_VAR': 54489,
#  'PREV_LAST24M_APPLICATION_CREDIT_RATIO_MIN': 56455,
#  'PREV_LAST24M_APPLICATION_CREDIT_RATIO_MEAN': 56455,
#  'PREV_LAST24M_APPLICATION_CREDIT_RATIO_MAX': 56455,
#  'PREV_LAST24M_AMT_ANNUITY_MEAN': 57960,
#  'PREV_LAST24M_AMT_ANNUITY_MAX': 57960,
#  'PREV_LAST24M_SIMPLE_INTERESTS_MEAN': 57963,
#  'PREV_LAST24M_SIMPLE_INTERESTS_MAX': 57963,
#  'CLD_CONCRED_CNT_CREDIT_PROLONG_MAX': 60412,
#  'CLD_CONCRED_CNT_CREDIT_PROLONG': 60412,
#  'CLD_CONCRED_COUNT': 60412,
#  'CLD_CONCRED_AMT_CREDIT_SUM': 60412,
#  'CLD_CONCRED_AMT_CREDIT_SUM_MAX': 60412,
#  'OCCUPATION_TYPE': 67535,
#  'POS_DPD_LAST_12_MONTHS': 70375,
#  'PREV_LAST24M_DAYS_LAST_DUE_1ST_VERSION_MEAN': 71543,
#  'PREV_LAST24M_DAYS_LAST_DUE_1ST_VERSION_MAX': 71543,
#  'PREV_LAST24M_DAYS_LAST_DUE_1ST_VERSION_MIN': 71543,
#  'PREV_Cash_DAYS_DECISION_MAX': 95341,
#  'PREV_Cash_APPLICATION_CREDIT_DIFF_MIN': 95341,
#  'PREV_Cash_AMT_CREDIT_SUM': 95341,
#  'PREV_LAST12M_DAYS_DECISION_MIN': 98157,
#  'PREV_LAST12M_DAYS_DECISION_MEAN': 98157,
#  'PREV_LAST12M_NAME_CONTRACT_TYPE_Consumer loans_MEAN': 98157,
#  'PREV_LAST12M_NAME_CONTRACT_TYPE_Revolving loans_MEAN': 98157,
#  'PREV_LAST12M_AMT_CREDIT_SUM': 98157,
#  'PREV_LAST12M_NAME_CONTRACT_TYPE_Cash loans_MEAN': 98157,
#  'PREV_LAST12M_APPLICATION_CREDIT_DIFF_MIN': 98157,
#  'POS_DPD_LAST_6_MONTHS': 99102,
#  'ACT_CONCRED_CNT_CREDIT_PROLONG': 101544,
#  'ACT_CONCRED_CNT_CREDIT_PROLONG_MAX': 101544,
#  'ACT_CONCRED_AMT_CREDIT_SUM_MAX': 101544,
#  'ACT_CONCRED_AMT_CREDIT_SUM_DEBT': 101544,
#  'ACT_CONCRED_COUNT': 101544,
#  'ACT_CONCRED_AMT_CREDIT_SUM': 101544,
#  'EMERGENCYSTATE_MODE': 102207,
#  'TOTALAREA_MODE': 104078,
#  'D1_CLD_CONCRED_CNT_CREDIT_PROLONG': 104331,
#  'D1_CLD_CONCRED_AMT_CREDIT_SUM_MAX': 104331,
#  'D1_CLD_CONCRED_COUNT': 104331,
#  'D1_CLD_CONCRED_CNT_CREDIT_PROLONG_MAX': 104331,
#  'D1_CLD_CONCRED_AMT_CREDIT_SUM': 104331,
#  'YEARS_BEGINEXPLUATATION_MEDI': 105172,
#  'YEARS_BEGINEXPLUATATION_MODE': 105172,
#  'YEARS_BEGINEXPLUATATION_AVG': 105172,
#  'PREV_Consumer_APPLICATION_CREDIT_DIFF_VAR': 105265,
#  'FLOORSMAX_AVG': 107258,
#  'FLOORSMAX_MEDI': 107258,
#  'FLOORSMAX_MODE': 107258,
#  'LIVINGAREA_AVG': 108185,
#  'LIVINGAREA_MEDI': 108185,
#  'LIVINGAREA_MODE': 108185,
#  'HOUSETYPE_MODE': 108201,
#  'ENTRANCES_MODE': 108511,
#  'ENTRANCES_MEDI': 108511,
#  'ENTRANCES_AVG': 108511,
#  'APARTMENTS_AVG': 109319,
#  'APARTMENTS_MEDI': 109319,
#  'APARTMENTS_MODE': 109319,
#  'PREV_Consumer_SIMPLE_INTERESTS_VAR': 109333,
#  'WALLSMATERIAL_MODE': 109590,
#  'PREV_Cash_APPLICATION_CREDIT_RATIO_MEAN': 110754,
#  'PREV_Cash_APPLICATION_CREDIT_RATIO_MIN': 110754,
#  'PREV_Cash_APPLICATION_CREDIT_RATIO_MAX': 110754,
#  'PREV_Cash_CNT_PAYMENT_MEAN': 110880,
#  'PREV_Cash_SIMPLE_INTERESTS_MAX': 110880,
#  'PREV_Cash_SIMPLE_INTERESTS_MEAN': 110880,
#  'PREV_Cash_SIMPLE_INTERESTS_MIN': 110880,
#  'PREV_Cash_AMT_ANNUITY_MEAN': 110880,
#  'PREV_Cash_AMT_ANNUITY_MAX': 110880,
#  'ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT': 111312,
#  'ACT_CREDCARD_AMT_CREDIT_SUM_DEBT': 111312,
#  'ACT_CREDCARD_AMT_CREDIT_SUM_MAX': 111312,
#  'ACT_CREDCARD_AMT_CREDIT_SUM': 111312,
#  'ACT_CREDCARD_COUNT': 111312,
#  'ACT_CREDCARD_CNT_CREDIT_PROLONG_MAX': 111312,
#  'ACT_CREDCARD_CNT_CREDIT_PROLONG': 111312,
#  'ACT_CONCRED_AMT_CREDIT_SUM_DEBT_MAX': 111884,
#  'ELEVATORS_AVG': 114839,
#  'ELEVATORS_MEDI': 114839,
#  'ELEVATORS_MODE': 114839,
#  'PREV_LAST12M_APPLICATION_CREDIT_RATIO_MAX': 116162,
#  'PREV_LAST12M_APPLICATION_CREDIT_RATIO_MEAN': 116162,
#  'PREV_LAST12M_APPLICATION_CREDIT_RATIO_MIN': 116162,
#  'PREV_ACTIVE_CNT_PAYMENT_SUM': 116971,
#  'PREV_ACTIVE_AMT_APPLICATION_MEAN': 116971,
#  'PREV_ACTIVE_AMT_APPLICATION_MAX': 116971,
#  'PREV_ACTIVE_AMT_ANNUITY_SUM': 116971,
#  'PREV_ACTIVE_CNT_PAYMENT_MEAN': 116971,
#  'PREV_ACTIVE_AMT_CREDIT_SUM': 116971,
#  'PREV_ACTIVE_AMT_ANNUITY_MAX': 116971,
#  'PREV_ACTIVE_SK_ID_PREV_NUNIQUE': 116971,
#  'PREV_ACTIVE_DAYS_LAST_DUE_1ST_VERSION_MAX': 116971,
#  'PREV_ACTIVE_DAYS_LAST_DUE_1ST_VERSION_MEAN': 116971,
#  'PREV_ACTIVE_DAYS_DECISION_MIN': 116971,
#  'PREV_ACTIVE_AMT_PAYMENT_SUM': 116971,
#  'PREV_ACTIVE_DAYS_DECISION_MEAN': 116971,
#  'PREV_ACTIVE_REMAINING_DEBT_SUM': 116971,
#  'PREV_ACTIVE_DAYS_LAST_DUE_1ST_VERSION_MIN': 116971,
#  'TOTAL_REPAYMENT_RATIO': 117010,
#  'PREV_ACTIVE_SIMPLE_INTERESTS_MEAN': 117153,
#  'ACT_CREDCARD_AMT_CREDIT_SUM_DEBT_MAX': 117397,
#  'PREV_LAST12M_AMT_ANNUITY_MEAN': 117844,
#  'PREV_LAST12M_AMT_ANNUITY_MAX': 117844,
#  'PREV_LAST12M_SIMPLE_INTERESTS_MEAN': 117848,
#  'PREV_LAST12M_SIMPLE_INTERESTS_MAX': 117848,
#  'CLD_CONCRED_AMT_CREDIT_MAX_OVERDUE': 118748,
#  'NONLIVINGAREA_MODE': 118862,
#  'NONLIVINGAREA_AVG': 118862,
#  'NONLIVINGAREA_MEDI': 118862,
#  'EXT_SOURCE_1': 121437,
#  'D2_CLD_CONCRED_AMT_CREDIT_SUM_MAX': 122863,
#  'D2_CLD_CONCRED_AMT_CREDIT_SUM': 122863,
#  'D2_CLD_CONCRED_COUNT': 122863,
#  'D2_CLD_CONCRED_CNT_CREDIT_PROLONG_MAX': 122863,
#  'D2_CLD_CONCRED_CNT_CREDIT_PROLONG': 122863,
#  'PREV_Cash_DAYS_LAST_DUE_1ST_VERSION_MEAN': 125072,
#  'PREV_Cash_DAYS_LAST_DUE_1ST_VERSION_MAX': 125072,
#  'BASEMENTAREA_MODE': 126083,
#  'BASEMENTAREA_AVG': 126083,
#  'BASEMENTAREA_MEDI': 126083,
#  'ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 126772,
#  'LANDAREA_MODE': 127915,
#  'LANDAREA_AVG': 127915,
#  'LANDAREA_MEDI': 127915,
#  'PREV_ACTIVE_REPAYMENT_RATIO_MEAN': 128753,
#  'PREV_ACTIVE_INSTALMENT_PAYMENT_DIFF_MEAN': 128753,
#  'PREV_ACTIVE_REMAINING_DEBT_MEAN': 128753,
#  'PREV_ACTIVE_REMAINING_DEBT_MAX': 128753,
#  'PREV_ACTIVE_INSTALMENT_PAYMENT_DIFF_MAX': 128753,
#  'PREV_Cash_APPLICATION_CREDIT_DIFF_VAR': 131435,
#  'D3_CLD_CONCRED_CNT_CREDIT_PROLONG': 138968,
#  'D3_CLD_CONCRED_CNT_CREDIT_PROLONG_MAX': 138968,
#  'D3_CLD_CONCRED_AMT_CREDIT_SUM': 138968,
#  'D3_CLD_CONCRED_AMT_CREDIT_SUM_MAX': 138968,
#  'D3_CLD_CONCRED_COUNT': 138968,
#  'D1_ACT_CONCRED_CNT_CREDIT_PROLONG': 140372,
#  'D1_ACT_CONCRED_AMT_CREDIT_SUM_DEBT': 140372,
#  'D1_ACT_CONCRED_COUNT': 140372,
#  'D1_ACT_CONCRED_AMT_CREDIT_SUM_MAX': 140372,
#  'D1_ACT_CONCRED_AMT_CREDIT_SUM': 140372,
#  'D1_ACT_CONCRED_CNT_CREDIT_PROLONG_MAX': 140372,
#  'PREV_LAST12M_DAYS_LAST_DUE_1ST_VERSION_MAX': 140716,
#  'PREV_LAST12M_DAYS_LAST_DUE_1ST_VERSION_MEAN': 140716,
#  'PREV_LAST12M_DAYS_LAST_DUE_1ST_VERSION_MIN': 140716,
#  'OWN_CAR_AGE': 141977,
#  'YEARS_BUILD_AVG': 143253,
#  'YEARS_BUILD_MODE': 143253,
#  'YEARS_BUILD_MEDI': 143253,
#  'PREV_REFUSED_NAME_CONTRACT_TYPE_Revolving loans_MEAN': 145045,
#  'PREV_REFUSED_NAME_CONTRACT_TYPE_Cash loans_MEAN': 145045,
#  'PREV_REFUSED_NAME_CONTRACT_TYPE_Consumer loans_MEAN': 145045,
#  'PREV_REFUSED_APPLICATION_CREDIT_DIFF_MAX': 145045,
#  'PREV_REFUSED_APPLICATION_CREDIT_DIFF_MIN': 145045,
#  'PREV_REFUSED_DAYS_DECISION_MEAN': 145045,
#  'PREV_REFUSED_DAYS_DECISION_MAX': 145045,
#  'PREV_REFUSED_APPLICATION_CREDIT_DIFF_MEAN': 145045,
#  'PREV_REFUSED_AMT_CREDIT_MAX': 145045,
#  'PREV_REFUSED_AMT_CREDIT_MIN': 145045,
#  'PREV_REFUSED_AMT_APPLICATION_MEAN': 145045,
#  'PREV_REFUSED_AMT_APPLICATION_MAX': 145045,
#  'PREV_REFUSED_DAYS_DECISION_MIN': 145045,
#  'FLOORSMIN_AVG': 146179,
#  'FLOORSMIN_MODE': 146179,
#  'FLOORSMIN_MEDI': 146179,
#  'LIVINGAPARTMENTS_AVG': 147319,
#  'LIVINGAPARTMENTS_MEDI': 147319,
#  'LIVINGAPARTMENTS_MODE': 147319,
#  'FONDKAPREMONT_MODE': 147322,
#  'D1_ACT_CONCRED_AMT_CREDIT_SUM_DEBT_MAX': 148147,
#  'PREV_REFUSED_APPLICATION_CREDIT_RATIO_MEAN': 148536,
#  'PREV_REFUSED_APPLICATION_CREDIT_RATIO_MIN': 148536,
#  'NONLIVINGAPARTMENTS_MEDI': 149634,
#  'NONLIVINGAPARTMENTS_AVG': 149634,
#  'NONLIVINGAPARTMENTS_MODE': 149634,
#  'COMMONAREA_AVG': 150483,
#  'COMMONAREA_MEDI': 150483,
#  'COMMONAREA_MODE': 150483,
#  'BB_DPD_120_FLAG': 150819,
#  'BB_DPD_91_120_FLAG': 150819,
#  'BB_DPD_61_90_FLAG': 150819,
#  'BB_DPD_31_60_FLAG': 150819,
#  'BB_DPD_1_30_FLAG': 150819,
#  'BB_DPD_FLAG': 150819,
#  'PREV_REFUSED_CNT_PAYMENT_MAX': 151188,
#  'PREV_REFUSED_CNT_PAYMENT_MEAN': 151188,
#  'PREV_Cash_SIMPLE_INTERESTS_VAR': 154603,
#  'D1_CLD_CONCRED_AMT_CREDIT_MAX_OVERDUE': 154806,
#  'ACT_CONCRED_AMT_CREDIT_MAX_OVERDUE': 162394,
#  'POS_DPD_LAST_1_MONTH': 167450,
#  'CLD_CREDCARD_AMT_CREDIT_SUM': 168756,
#  'CLD_CREDCARD_AMT_CREDIT_SUM_MAX': 168756,
#  'CLD_CREDCARD_CNT_CREDIT_PROLONG': 168756,
#  'CLD_CREDCARD_CNT_CREDIT_PROLONG_MAX': 168756,
#  'CLD_CREDCARD_COUNT': 168756,
#  'CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT': 168756,
#  'ACT_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 169955,
#  'D3_ACT_CREDCARD_CNT_CREDIT_PROLONG': 173203,
#  'D3_ACT_CREDCARD_CNT_CREDIT_PROLONG_MAX': 173203,
#  'D3_ACT_CREDCARD_AMT_CREDIT_SUM': 173203,
#  'D3_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT': 173203,
#  'D3_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT': 173203,
#  'D3_ACT_CREDCARD_COUNT': 173203,
#  'D3_ACT_CREDCARD_AMT_CREDIT_SUM_MAX': 173203,
#  'D1_ACT_CREDCARD_AMT_CREDIT_SUM_MAX': 174760,
#  'D1_ACT_CREDCARD_CNT_CREDIT_PROLONG_MAX': 174760,
#  'D1_ACT_CREDCARD_CNT_CREDIT_PROLONG': 174760,
#  'D1_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT': 174760,
#  'D1_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT': 174760,
#  'D1_ACT_CREDCARD_COUNT': 174760,
#  'D1_ACT_CREDCARD_AMT_CREDIT_SUM': 174760,
#  'D3_CLD_CONCRED_AMT_CREDIT_MAX_OVERDUE': 174926,
#  'D2_ACT_CONCRED_COUNT': 175007,
#  'D2_ACT_CONCRED_AMT_CREDIT_SUM_DEBT': 175007,
#  'D2_ACT_CONCRED_AMT_CREDIT_SUM_MAX': 175007,
#  'D2_ACT_CONCRED_AMT_CREDIT_SUM': 175007,
#  'D2_ACT_CONCRED_CNT_CREDIT_PROLONG': 175007,
#  'D2_ACT_CONCRED_CNT_CREDIT_PROLONG_MAX': 175007,
#  'PREV_ACTIVE_AMT_DOWN_PAYMENT_MEAN': 175715,
#  'PREV_ACTIVE_AMT_DOWN_PAYMENT_MAX': 175715,
#  'D3_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT_MAX': 175887,
#  'PREV_REFUSED_APPLICATION_CREDIT_DIFF_VAR': 177710,
#  'D2_ACT_CREDCARD_CNT_CREDIT_PROLONG': 177978,
#  'D2_ACT_CREDCARD_AMT_CREDIT_SUM': 177978,
#  'D2_ACT_CREDCARD_AMT_CREDIT_SUM_MAX': 177978,
#  'D2_ACT_CREDCARD_CNT_CREDIT_PROLONG_MAX': 177978,
#  'D2_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT': 177978,
#  'D2_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT': 177978,
#  'D2_ACT_CREDCARD_COUNT': 177978,
#  'D1_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT_MAX': 178460,
#  'D3_ACT_CONCRED_AMT_CREDIT_SUM_DEBT': 179516,
#  'D3_ACT_CONCRED_COUNT': 179516,
#  'D3_ACT_CONCRED_AMT_CREDIT_SUM_MAX': 179516,
#  'D3_ACT_CONCRED_AMT_CREDIT_SUM': 179516,
#  'D3_ACT_CONCRED_CNT_CREDIT_PROLONG_MAX': 179516,
#  'D3_ACT_CONCRED_CNT_CREDIT_PROLONG': 179516,
#  'D2_ACT_CONCRED_AMT_CREDIT_SUM_DEBT_MAX': 179925,
#  'D1_ACT_CONCRED_AMT_CREDIT_MAX_OVERDUE': 180033,
#  'D2_CLD_CONCRED_AMT_CREDIT_MAX_OVERDUE': 180614,
#  'D3_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 181246,
#  'D2_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT_MAX': 181395,
#  'D1_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 183118,
#  'CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 184338,
#  'D2_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 185043,
#  'D3_ACT_CONCRED_AMT_CREDIT_SUM_DEBT_MAX': 185357,
#  'BB_DPD_MAX': 193545,
#  'CLD_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 195208,
#  'D4_ACT_CREDCARD_CNT_CREDIT_PROLONG': 195585,
#  'D4_ACT_CREDCARD_AMT_CREDIT_SUM': 195585,
#  'D4_ACT_CREDCARD_AMT_CREDIT_SUM_MAX': 195585,
#  'D4_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT': 195585,
#  'D4_ACT_CREDCARD_CNT_CREDIT_PROLONG_MAX': 195585,
#  'D4_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT': 195585,
#  'D4_ACT_CREDCARD_COUNT': 195585,
#  'D1_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT': 196922,
#  'D1_CLD_CREDCARD_CNT_CREDIT_PROLONG': 196922,
#  'D1_CLD_CREDCARD_CNT_CREDIT_PROLONG_MAX': 196922,
#  'D1_CLD_CREDCARD_AMT_CREDIT_SUM': 196922,
#  'D1_CLD_CREDCARD_AMT_CREDIT_SUM_MAX': 196922,
#  'D1_CLD_CREDCARD_COUNT': 196922,
#  'D4_ACT_CREDCARD_AMT_CREDIT_SUM_DEBT_MAX': 197490,
#  'D3_ACT_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 199300,
#  'D2_ACT_CONCRED_AMT_CREDIT_MAX_OVERDUE': 199772,
#  'D4_ACT_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 199846,
#  'D2_ACT_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 201247,
#  'D2_CLD_CREDCARD_CNT_CREDIT_PROLONG': 201615,
#  'D2_CLD_CREDCARD_CNT_CREDIT_PROLONG_MAX': 201615,
#  'D2_CLD_CREDCARD_AMT_CREDIT_SUM': 201615,
#  'D2_CLD_CREDCARD_AMT_CREDIT_SUM_MAX': 201615,
#  'D2_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT': 201615,
#  'D2_CLD_CREDCARD_COUNT': 201615,
#  'D1_ACT_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 201792,
#  'D3_CLD_CREDCARD_CNT_CREDIT_PROLONG': 203146,
#  'D3_CLD_CREDCARD_CNT_CREDIT_PROLONG_MAX': 203146,
#  'D3_CLD_CREDCARD_AMT_CREDIT_SUM': 203146,
#  'D3_CLD_CREDCARD_AMT_CREDIT_SUM_MAX': 203146,
#  'D3_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT': 203146,
#  'D3_CLD_CREDCARD_COUNT': 203146,
#  'CLD_OTHER_AMT_CREDIT_SUM': 203172,
#  'CLD_OTHER_AMT_CREDIT_SUM_DEBT': 203172,
#  'CLD_OTHER_AMT_ANNUITY_DEBT': 203172,
#  'CLD_OTHER_COUNT': 203172,
#  'CLD_OTHER_AMT_CREDIT_SUM_MAX': 203173,
#  'D4_CLD_CREDCARD_COUNT': 203229,
#  'D4_CLD_CREDCARD_CNT_CREDIT_PROLONG': 203229,
#  'D4_CLD_CREDCARD_CNT_CREDIT_PROLONG_MAX': 203229,
#  'D4_CLD_CREDCARD_AMT_CREDIT_SUM': 203229,
#  'D4_CLD_CREDCARD_AMT_CREDIT_SUM_MAX': 203229,
#  'D4_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT': 203229,
#  'D1_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 203282,
#  'D4_ACT_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 204467,
#  'CLD_OTHER_AMT_CREDIT_SUM_DEBT_MAX': 205351,
#  'D3_ACT_CONCRED_AMT_CREDIT_MAX_OVERDUE': 206424,
#  'D2_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 206568,
#  'ACT_OTHER_AMT_CREDIT_SUM': 207838,
#  'ACT_OTHER_AMT_CREDIT_SUM_DEBT': 207838,
#  'ACT_OTHER_AMT_ANNUITY': 207838,
#  'ACT_OTHER_COUNT': 207838,
#  'ACT_OTHER_AMT_CREDIT_SUM_MAX': 207839,
#  'D3_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 207881,
#  'ACT_MORTG_CREDIT_DAY_OVERDUE': 207985,
#  'ACT_MORTG_DAYS_CREDIT': 207985,
#  'ACT_MORTG_AMT_CREDIT_SUM': 207985,
#  'ACT_MORTG_CNT_CREDIT_PROLONG': 207985,
#  'ACT_MORTG_DAYS_CREDIT_UPDATE': 207985,
#  'ACT_MORTG_COUNT': 207985,
#  'ACT_MORTG_AMT_CREDIT_SUM_OVERDUE': 207985,
#  'D4_CLD_CREDCARD_AMT_CREDIT_SUM_LIMIT_MAX': 208216,
#  'ACT_MORTG_DAYS_CREDIT_ENDDATE': 208297,
#  'D1_CLD_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 208709,
#  'ACT_MORTG_AMT_CREDIT_SUM_DEBT': 208845,
#  'ACT_OTHER_AMT_CREDIT_SUM_DEBT_MAX': 209145,
#  'ACT_MORTG_AMT_CREDIT_SUM_LIMIT': 209376,
#  'D2_CLD_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 209749,
#  'D4_CLD_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 210171,
#  'D3_CLD_CREDCARD_AMT_CREDIT_MAX_OVERDUE': 210440,
#  'CLD_OTHER_AMT_ANNUITY_DEBT_MAX': 212138,
#  'CLD_OTHER_AMT_CREDIT_MAX_OVERDUE': 212211,
#  'CLD_MORTG_AMT_CREDIT_SUM': 212533,
#  'CLD_MORTG_COUNT': 212533,
#  'CLD_MORTG_CNT_CREDIT_PROLONG': 212533,
#  'CLD_MORTG_DAYS_ENDDATE_FACT': 212533,
#  'CLD_MORTG_AMT_CREDIT_SUM_OVERDUE': 212533,
#  'CLD_MORTG_CREDIT_DAY_OVERDUE': 212533,
#  'CLD_MORTG_DAYS_CREDIT': 212533,
#  'CLD_MORTG_SK_ID_BUREAU': 212533,
#  'CLD_MORTG_DAYS_CREDIT_UPDATE': 212533,
#  'CLD_MORTG_DAYS_CREDIT_ENDDATE': 212642,
#  'ACT_OTHER_AMT_CREDIT_MAX_OVERDUE': 212979,
#  'ACT_OTHER_AMT_ANNUITY_MAX': 213136,
#  'CLD_MORTG_AMT_CREDIT_SUM_DEBT': 213252,
#  'ACT_MORTG_AMT_ANNUITY': 213300,
#  'CLD_MORTG_AMT_CREDIT_SUM_LIMIT': 213566,
#  'ACT_MORTG_AMT_CREDIT_MAX_OVERDUE': 214263,
#  'CLD_MORTG_AMT_ANNUITY': 214620,
#  'CLD_MORTG_AMT_CREDIT_MAX_OVERDUE': 214642}

# %%
model_file.to_csv(os.path.join(model_file_output_dir,'model_file.csv'))
model_file.to_csv(os.path.join(engineered_data_dir,'model_file.csv'))

model_file.to_pickle(os.path.join(model_file_output_dir,'model_file.pkl'))
model_file.to_pickle(os.path.join(engineered_data_dir,'model_file.pkl'))
